# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
units = "imperial" 

#Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  url + "&q=" + city
    print(city_url)
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=st. john's
# Processing Record 1 of Set 1 | st. john's
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=armacao de buzios
# Processing Record 2 of Set 1 | armacao de buzios
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port-aux-francais
# Processing Record 3 of Set 1 | port-aux-francais
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port mathurin
# Processing Record 4 of Set 1 | port mathurin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=fort mcmurray
# Processing Record 5 of Set 1 | fort mcmurray
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hawaiian paradise park
# Processing Record 6 of Set 1 | hawaiian paradise park
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hellertown
# Processing Record 7 of Set 1 | hellertown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tsiombe
# Processing Record 8 of Set 1 | tsiombe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=holualoa
# Processing Record 9 of Set 1 | holualoa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lebu
# Processing Record 10 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=adamstown
# Processing Record 11 of Set 1 | adamstown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tindouf
# Processing Record 12 of Set 1 | tindouf
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=keetmanshoop
# Processing Record 13 of Set 1 | keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yellowknife
# Processing Record 14 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kruisfontein
# Processing Record 15 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=shimokizukuri
# Processing Record 16 of Set 1 | shimokizukuri
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ushuaia
# Processing Record 17 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kununurra
# Processing Record 18 of Set 1 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=villa gesell
# Processing Record 19 of Set 1 | villa gesell
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=whitehorse
# Processing Record 20 of Set 1 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=udachny
# Processing Record 21 of Set 1 | udachny
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=talnakh
# Processing Record 22 of Set 1 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bolobo
# Processing Record 23 of Set 1 | bolobo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=giyani
# Processing Record 24 of Set 1 | giyani
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mount pearl
# Processing Record 25 of Set 1 | mount pearl
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=longyearbyen
# Processing Record 26 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=east london
# Processing Record 27 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=westport
# Processing Record 28 of Set 1 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=jamestown
# Processing Record 29 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=edinburgh of the seven seas
# Processing Record 30 of Set 1 | edinburgh of the seven seas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=invercargill
# Processing Record 31 of Set 1 | invercargill
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bima
# Processing Record 32 of Set 1 | bima
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=gadzhiyevo
# Processing Record 33 of Set 1 | gadzhiyevo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vadso
# Processing Record 34 of Set 1 | vadso
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ghat
# Processing Record 35 of Set 1 | ghat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=iqaluit
# Processing Record 36 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tamandare
# Processing Record 37 of Set 1 | tamandare
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sokhumi
# Processing Record 38 of Set 1 | sokhumi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=carbonear
# Processing Record 39 of Set 1 | carbonear
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=pizarro
# Processing Record 40 of Set 1 | pizarro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vallenar
# Processing Record 41 of Set 1 | vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=las veredas
# Processing Record 42 of Set 1 | las veredas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=petropavlovsk-kamchatsky
# Processing Record 43 of Set 1 | petropavlovsk-kamchatsky
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=acarau
# Processing Record 44 of Set 1 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=west island
# Processing Record 45 of Set 1 | west island
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=devinuwara
# Processing Record 46 of Set 1 | devinuwara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=marconia
# Processing Record 47 of Set 1 | marconia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=prince albert
# Processing Record 48 of Set 1 | prince albert
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ugoofaaru
# Processing Record 49 of Set 1 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bethel
# Processing Record 50 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=isafjordur
# Processing Record 0 of Set 2 | isafjordur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=utrik
# Processing Record 1 of Set 2 | utrik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=santa fe
# Processing Record 2 of Set 2 | santa fe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=alta
# Processing Record 3 of Set 2 | alta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vorgashor
# Processing Record 4 of Set 2 | vorgashor
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=guerrero negro
# Processing Record 5 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=albany
# Processing Record 6 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=woolgoolga
# Processing Record 7 of Set 2 | woolgoolga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=greenville
# Processing Record 8 of Set 2 | greenville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=guiria
# Processing Record 9 of Set 2 | guiria
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=olovyannaya
# Processing Record 10 of Set 2 | olovyannaya
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=wickenburg
# Processing Record 11 of Set 2 | wickenburg
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=puerto baquerizo moreno
# Processing Record 12 of Set 2 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=salida
# Processing Record 13 of Set 2 | salida
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=fortaleza
# Processing Record 14 of Set 2 | fortaleza
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=amahai
# Processing Record 15 of Set 2 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cabo san lucas
# Processing Record 16 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bojnurd
# Processing Record 17 of Set 2 | bojnurd
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tangalle
# Processing Record 18 of Set 2 | tangalle
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=papatowai
# Processing Record 19 of Set 2 | papatowai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=waitangi
# Processing Record 20 of Set 2 | waitangi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=avarua
# Processing Record 21 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bredasdorp
# Processing Record 22 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=labytnangi
# Processing Record 23 of Set 2 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=prievidza
# Processing Record 24 of Set 2 | prievidza
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tongren
# Processing Record 25 of Set 2 | tongren
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=gamay
# Processing Record 26 of Set 2 | gamay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=wailua homesteads
# Processing Record 27 of Set 2 | wailua homesteads
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sosenskiy
# Processing Record 28 of Set 2 | sosenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tazovsky
# Processing Record 29 of Set 2 | tazovsky
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=gorontalo
# Processing Record 30 of Set 2 | gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=aykhal
# Processing Record 31 of Set 2 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=newman
# Processing Record 32 of Set 2 | newman
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bilibino
# Processing Record 33 of Set 2 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ringkobing
# Processing Record 34 of Set 2 | ringkobing
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=marzahn
# Processing Record 35 of Set 2 | marzahn
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=quatre cocos
# Processing Record 36 of Set 2 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hammerfest
# Processing Record 37 of Set 2 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=atafu village
# Processing Record 38 of Set 2 | atafu village
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tiksi
# Processing Record 39 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=shendi
# Processing Record 40 of Set 2 | shendi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kingston
# Processing Record 41 of Set 2 | kingston
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=reggane
# Processing Record 42 of Set 2 | reggane
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zouerate
# Processing Record 43 of Set 2 | zouerate
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=portland
# Processing Record 44 of Set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=pagar alam
# Processing Record 45 of Set 2 | pagar alam
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=aasiaat
# Processing Record 46 of Set 2 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=dwarka
# Processing Record 47 of Set 2 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=galveston
# Processing Record 48 of Set 2 | galveston
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=thompson
# Processing Record 49 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=campbell river
# Processing Record 0 of Set 3 | campbell river
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lukolela
# Processing Record 1 of Set 3 | lukolela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ribeira grande
# Processing Record 2 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=dakhla
# Processing Record 3 of Set 3 | dakhla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port saint john's
# Processing Record 4 of Set 3 | port saint john's
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=blackmans bay
# Processing Record 5 of Set 3 | blackmans bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cobram
# Processing Record 6 of Set 3 | cobram
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tamanrasset
# Processing Record 7 of Set 3 | tamanrasset
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mubi
# Processing Record 8 of Set 3 | mubi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=maqat
# Processing Record 9 of Set 3 | maqat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vuktyl
# Processing Record 10 of Set 3 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tranovaho
# Processing Record 11 of Set 3 | tranovaho
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port elizabeth
# Processing Record 12 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=college
# Processing Record 13 of Set 3 | college
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=grytviken
# Processing Record 14 of Set 3 | grytviken
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cortez
# Processing Record 15 of Set 3 | cortez
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=melipilla
# Processing Record 16 of Set 3 | melipilla
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=carnarvon
# Processing Record 17 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=qaqortoq
# Processing Record 18 of Set 3 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=saudarkrokur
# Processing Record 19 of Set 3 | saudarkrokur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=weno
# Processing Record 20 of Set 3 | weno
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=katsuura
# Processing Record 21 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vanimo
# Processing Record 22 of Set 3 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=harper
# Processing Record 23 of Set 3 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=rocky mountain house
# Processing Record 24 of Set 3 | rocky mountain house
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lompoc
# Processing Record 25 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hayma'
# Processing Record 26 of Set 3 | hayma'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sao joao da barra
# Processing Record 27 of Set 3 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hasaki
# Processing Record 28 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kapa'a
# Processing Record 29 of Set 3 | kapa'a
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=iskateley
# Processing Record 30 of Set 3 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tolanaro
# Processing Record 31 of Set 3 | tolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cargados carajos
# Processing Record 32 of Set 3 | cargados carajos
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hermanus
# Processing Record 33 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vanino
# Processing Record 34 of Set 3 | vanino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ji'an
# Processing Record 35 of Set 3 | ji'an
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=pandan
# Processing Record 36 of Set 3 | pandan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=komsomol'skiy
# Processing Record 37 of Set 3 | komsomol'skiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=dudinka
# Processing Record 38 of Set 3 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sangod
# Processing Record 39 of Set 3 | sangod
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=rundu
# Processing Record 40 of Set 3 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zaozersk
# Processing Record 41 of Set 3 | zaozersk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bridgewater
# Processing Record 42 of Set 3 | bridgewater
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kayangel
# Processing Record 43 of Set 3 | kayangel
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=haiku-pauwela
# Processing Record 44 of Set 3 | haiku-pauwela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=puerto natales
# Processing Record 45 of Set 3 | puerto natales
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bel ombre
# Processing Record 46 of Set 3 | bel ombre
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yangshuo
# Processing Record 47 of Set 3 | yangshuo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=progreso
# Processing Record 48 of Set 3 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kodiak
# Processing Record 49 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=palmer
# Processing Record 0 of Set 4 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=margaret river
# Processing Record 1 of Set 4 | margaret river
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=pangody
# Processing Record 2 of Set 4 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=palestine
# Processing Record 3 of Set 4 | palestine
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=new norfolk
# Processing Record 4 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ilulissat
# Processing Record 5 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=polyarnyy
# Processing Record 6 of Set 4 | polyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=egersund
# Processing Record 7 of Set 4 | egersund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=illizi
# Processing Record 8 of Set 4 | illizi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vylkove
# Processing Record 9 of Set 4 | vylkove
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ancud
# Processing Record 10 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=saipan
# Processing Record 11 of Set 4 | saipan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=monrovia
# Processing Record 12 of Set 4 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=keflavik
# Processing Record 13 of Set 4 | keflavik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=antalaha
# Processing Record 14 of Set 4 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mchinji
# Processing Record 15 of Set 4 | mchinji
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mildura
# Processing Record 16 of Set 4 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=beylikova
# Processing Record 17 of Set 4 | beylikova
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zangguy
# Processing Record 18 of Set 4 | zangguy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ola
# Processing Record 19 of Set 4 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=taiohae
# Processing Record 20 of Set 4 | taiohae
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=banyo
# Processing Record 21 of Set 4 | banyo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=midvagur
# Processing Record 22 of Set 4 | midvagur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=chernyshevskiy
# Processing Record 23 of Set 4 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=shihezi
# Processing Record 24 of Set 4 | shihezi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=maloye ganyushkino
# Processing Record 25 of Set 4 | maloye ganyushkino
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kultali
# Processing Record 26 of Set 4 | kultali
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=brisas de zicatela
# Processing Record 27 of Set 4 | brisas de zicatela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=flying fish cove
# Processing Record 28 of Set 4 | flying fish cove
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=monaghan
# Processing Record 29 of Set 4 | monaghan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=laguna
# Processing Record 30 of Set 4 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=okhotsk
# Processing Record 31 of Set 4 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=glace bay
# Processing Record 32 of Set 4 | glace bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=constantia
# Processing Record 33 of Set 4 | constantia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=paradip garh
# Processing Record 34 of Set 4 | paradip garh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kone
# Processing Record 35 of Set 4 | kone
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sitka
# Processing Record 36 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=colac
# Processing Record 37 of Set 4 | colac
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kapoeta
# Processing Record 38 of Set 4 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=whakatane
# Processing Record 39 of Set 4 | whakatane
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=solnechnyy
# Processing Record 40 of Set 4 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hithadhoo
# Processing Record 41 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=itaituba
# Processing Record 42 of Set 4 | itaituba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=khandyga
# Processing Record 43 of Set 4 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=al manshah
# Processing Record 44 of Set 4 | al manshah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=rukban
# Processing Record 45 of Set 4 | rukban
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sheridan
# Processing Record 46 of Set 4 | sheridan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=xiaoweizhai
# Processing Record 47 of Set 4 | xiaoweizhai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=veraval
# Processing Record 48 of Set 4 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=georgetown
# Processing Record 49 of Set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=aleksandrovsk-sakhalinskiy
# Processing Record 0 of Set 5 | aleksandrovsk-sakhalinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=pacific grove
# Processing Record 1 of Set 5 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=igarka
# Processing Record 2 of Set 5 | igarka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bliss corner
# Processing Record 3 of Set 5 | bliss corner
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=slyudyanka
# Processing Record 4 of Set 5 | slyudyanka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=flin flon
# Processing Record 5 of Set 5 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lihue
# Processing Record 6 of Set 5 | lihue
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=enewetak
# Processing Record 7 of Set 5 | enewetak
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bonoua
# Processing Record 8 of Set 5 | bonoua
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sonsorol village
# Processing Record 9 of Set 5 | sonsorol village
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=olonkinbyen
# Processing Record 10 of Set 5 | olonkinbyen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=korostyshiv
# Processing Record 11 of Set 5 | korostyshiv
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yangor
# Processing Record 12 of Set 5 | yangor
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=santana do livramento
# Processing Record 13 of Set 5 | santana do livramento
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nova sintra
# Processing Record 14 of Set 5 | nova sintra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=saldanha
# Processing Record 15 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ketchikan
# Processing Record 16 of Set 5 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mugia
# Processing Record 17 of Set 5 | mugia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kavaratti
# Processing Record 18 of Set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sweetwater
# Processing Record 19 of Set 5 | sweetwater
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=isangel
# Processing Record 20 of Set 5 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=san pedro de macoris
# Processing Record 21 of Set 5 | san pedro de macoris
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=punta arenas
# Processing Record 22 of Set 5 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hamilton
# Processing Record 23 of Set 5 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=heihe
# Processing Record 24 of Set 5 | heihe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nuuk
# Processing Record 25 of Set 5 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=konosha
# Processing Record 26 of Set 5 | konosha
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nyurba
# Processing Record 27 of Set 5 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sao felix do xingu
# Processing Record 28 of Set 5 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=maceio
# Processing Record 29 of Set 5 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=rabo de peixe
# Processing Record 30 of Set 5 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kangding
# Processing Record 31 of Set 5 | kangding
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mamuju
# Processing Record 32 of Set 5 | mamuju
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=alaghsas
# Processing Record 33 of Set 5 | alaghsas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=envira
# Processing Record 34 of Set 5 | envira
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=robbah
# Processing Record 35 of Set 5 | robbah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lahore
# Processing Record 36 of Set 5 | lahore
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=koupela
# Processing Record 37 of Set 5 | koupela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nevada
# Processing Record 38 of Set 5 | nevada
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=springbok
# Processing Record 39 of Set 5 | springbok
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lautoka
# Processing Record 40 of Set 5 | lautoka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=velikovechnoye
# Processing Record 41 of Set 5 | velikovechnoye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=christchurch
# Processing Record 42 of Set 5 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mount gambier
# Processing Record 43 of Set 5 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kiuruvesi
# Processing Record 44 of Set 5 | kiuruvesi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=toga village
# Processing Record 45 of Set 5 | toga village
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yagry
# Processing Record 46 of Set 5 | yagry
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ta`u
# Processing Record 47 of Set 5 | ta`u
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=selty
# Processing Record 48 of Set 5 | selty
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=buka
# Processing Record 49 of Set 5 | buka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bayan nur
# Processing Record 0 of Set 6 | bayan nur
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vingt cinq
# Processing Record 1 of Set 6 | vingt cinq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=revda
# Processing Record 2 of Set 6 | revda
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=taperoa
# Processing Record 3 of Set 6 | taperoa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mahajanga
# Processing Record 4 of Set 6 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=gumdag
# Processing Record 5 of Set 6 | gumdag
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=usinsk
# Processing Record 6 of Set 6 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kidal
# Processing Record 7 of Set 6 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=strathmore
# Processing Record 8 of Set 6 | strathmore
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hojai
# Processing Record 9 of Set 6 | hojai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port pirie
# Processing Record 10 of Set 6 | port pirie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nova xavantina
# Processing Record 11 of Set 6 | nova xavantina
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=dauphin
# Processing Record 12 of Set 6 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=erdenet
# Processing Record 13 of Set 6 | erdenet
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=la passe
# Processing Record 14 of Set 6 | la passe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bardai
# Processing Record 15 of Set 6 | bardai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=puerto san carlos
# Processing Record 16 of Set 6 | puerto san carlos
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mangrol
# Processing Record 17 of Set 6 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kirakira
# Processing Record 18 of Set 6 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=fuvahmulah
# Processing Record 19 of Set 6 | fuvahmulah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=las khorey
# Processing Record 20 of Set 6 | las khorey
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=burang
# Processing Record 21 of Set 6 | burang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=rubtsovsk
# Processing Record 22 of Set 6 | rubtsovsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kerikeri
# Processing Record 23 of Set 6 | kerikeri
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=arrifes
# Processing Record 24 of Set 6 | arrifes
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=berezniki
# Processing Record 25 of Set 6 | berezniki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=fisterra
# Processing Record 26 of Set 6 | fisterra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=luganville
# Processing Record 27 of Set 6 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=san luis de la loma
# Processing Record 28 of Set 6 | san luis de la loma
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=neryungri
# Processing Record 29 of Set 6 | neryungri
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=robertsport
# Processing Record 30 of Set 6 | robertsport
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=brioude
# Processing Record 31 of Set 6 | brioude
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=neiafu
# Processing Record 32 of Set 6 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=trinity beach
# Processing Record 33 of Set 6 | trinity beach
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ust-nera
# Processing Record 34 of Set 6 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=richards bay
# Processing Record 35 of Set 6 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=uturoa
# Processing Record 36 of Set 6 | uturoa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=saynshand
# Processing Record 37 of Set 6 | saynshand
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=chonchi
# Processing Record 38 of Set 6 | chonchi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=samamea
# Processing Record 39 of Set 6 | samamea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kyabe
# Processing Record 40 of Set 6 | kyabe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nagqu
# Processing Record 41 of Set 6 | nagqu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=klyuchi
# Processing Record 42 of Set 6 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=elverum
# Processing Record 43 of Set 6 | elverum
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ilha de mocambique
# Processing Record 44 of Set 6 | ilha de mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=badger
# Processing Record 45 of Set 6 | badger
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port macquarie
# Processing Record 46 of Set 6 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mersa matruh
# Processing Record 47 of Set 6 | mersa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=jamaame
# Processing Record 48 of Set 6 | jamaame
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=safotu
# Processing Record 49 of Set 6 | safotu
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kristiansund
# Processing Record 0 of Set 7 | kristiansund
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=international falls
# Processing Record 1 of Set 7 | international falls
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=puerto ayora
# Processing Record 2 of Set 7 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=agat village
# Processing Record 3 of Set 7 | agat village
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=jiujiang
# Processing Record 4 of Set 7 | jiujiang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port alfred
# Processing Record 5 of Set 7 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nazyvayevsk
# Processing Record 6 of Set 7 | nazyvayevsk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yelizovo
# Processing Record 7 of Set 7 | yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=uaua
# Processing Record 8 of Set 7 | uaua
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=rosario do sul
# Processing Record 9 of Set 7 | rosario do sul
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=remire-montjoly
# Processing Record 48 of Set 10 | remire-montjoly
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sebdou
# Processing Record 49 of Set 10 | sebdou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=al jawf
# Processing Record 0 of Set 11 | al jawf
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=businga
# Processing Record 1 of Set 11 | businga
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=qarauyl
# Processing Record 2 of Set 11 | qarauyl
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=minas de marcona
# Processing Record 3 of Set 11 | minas de marcona
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ornskoldsvik
# Processing Record 4 of Set 11 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nikolayevsk-on-amure
# Processing Record 5 of Set 11 | nikolayevsk-on-amure
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ambodifotatra
# Processing Record 6 of Set 11 | ambodifotatra
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cuatro cienegas de carranza
# Processing Record 7 of Set 11 | cuatro cienegas de carranza
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mahishadal
# Processing Record 8 of Set 11 | mahishadal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=marang
# Processing Record 9 of Set 11 | marang
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yung shue wan
# Processing Record 10 of Set 11 | yung shue wan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zagora
# Processing Record 11 of Set 11 | zagora
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ahau
# Processing Record 12 of Set 11 | ahau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=strugi-krasnyye
# Processing Record 13 of Set 11 | strugi-krasnyye
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bargara
# Processing Record 14 of Set 11 | bargara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=severo-yeniseyskiy
# Processing Record 15 of Set 11 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lagoa
# Processing Record 16 of Set 11 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cartagena
# Processing Record 17 of Set 11 | cartagena
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bojia
# Processing Record 18 of Set 11 | bojia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=namibe
# Processing Record 19 of Set 11 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=niquero
# Processing Record 20 of Set 11 | niquero
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=itoman
# Processing Record 21 of Set 11 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=gueltat zemmour
# Processing Record 22 of Set 11 | gueltat zemmour
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=forster
# Processing Record 23 of Set 11 | forster
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=minot air force base
# Processing Record 24 of Set 11 | minot air force base
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bubaque
# Processing Record 25 of Set 11 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lazaro cardenas
# Processing Record 26 of Set 11 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=camargo
# Processing Record 27 of Set 11 | camargo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kourou
# Processing Record 28 of Set 11 | kourou
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kill devil hills
# Processing Record 29 of Set 11 | kill devil hills
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=muzayri'
# Processing Record 30 of Set 11 | muzayri'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mosjoen
# Processing Record 31 of Set 11 | mosjoen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kirensk
# Processing Record 32 of Set 11 | kirensk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=linton
# Processing Record 33 of Set 11 | linton
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=crane
# Processing Record 34 of Set 11 | crane
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=charleston
# Processing Record 35 of Set 11 | charleston
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=bir el ater
# Processing Record 36 of Set 11 | bir el ater
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=oodweyne
# Processing Record 37 of Set 11 | oodweyne
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=cheremukhovo
# Processing Record 38 of Set 11 | cheremukhovo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=filadelfia
# Processing Record 39 of Set 11 | filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=howrah
# Processing Record 40 of Set 11 | howrah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=okulovka
# Processing Record 41 of Set 11 | okulovka
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yelm
# Processing Record 42 of Set 11 | yelm
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ouadda
# Processing Record 43 of Set 11 | ouadda
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=taltal
# Processing Record 44 of Set 11 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tianpeng
# Processing Record 45 of Set 11 | tianpeng
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ruwandiz
# Processing Record 46 of Set 11 | ruwandiz
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kapit
# Processing Record 47 of Set 11 | kapit
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hirosaki
# Processing Record 48 of Set 11 | hirosaki
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=linxia chengguanzhen
# Processing Record 49 of Set 11 | linxia chengguanzhen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=penzance
# Processing Record 0 of Set 12 | penzance
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hono
# Processing Record 1 of Set 12 | hono
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=thames
# Processing Record 2 of Set 12 | thames
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ponta delgada
# Processing Record 3 of Set 12 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=thinadhoo
# Processing Record 4 of Set 12 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ijuw
# Processing Record 5 of Set 12 | ijuw
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=lerwick
# Processing Record 6 of Set 12 | lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=otsuchi
# Processing Record 7 of Set 12 | otsuchi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=i-n-salah
# Processing Record 8 of Set 12 | i-n-salah
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=piti village
# Processing Record 9 of Set 12 | piti village
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=mezhdurechensk
# Processing Record 10 of Set 12 | mezhdurechensk
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=taro
# Processing Record 11 of Set 12 | taro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zhosaly
# Processing Record 12 of Set 12 | zhosaly
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hilo
# Processing Record 13 of Set 12 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=queenstown
# Processing Record 14 of Set 12 | queenstown
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=guiuan
# Processing Record 15 of Set 12 | guiuan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=dunedin
# Processing Record 16 of Set 12 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=puerto maldonado
# Processing Record 17 of Set 12 | puerto maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=tadine
# Processing Record 18 of Set 12 | tadine
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=hudson
# Processing Record 19 of Set 12 | hudson
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=abraham's bay
# Processing Record 20 of Set 12 | abraham's bay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=touros
# Processing Record 21 of Set 12 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=ilhabela
# Processing Record 22 of Set 12 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=eyl
# Processing Record 23 of Set 12 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=barclayville
# Processing Record 24 of Set 12 | barclayville
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sturgeon bay
# Processing Record 25 of Set 12 | sturgeon bay
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=vrangel'
# Processing Record 26 of Set 12 | vrangel'
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=harrai
# Processing Record 27 of Set 12 | harrai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=pasan
# Processing Record 28 of Set 12 | pasan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=murzuq
# Processing Record 29 of Set 12 | murzuq
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=altai
# Processing Record 30 of Set 12 | altai
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=popondetta
# Processing Record 31 of Set 12 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=fort st. john
# Processing Record 32 of Set 12 | fort st. john
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=nemuro
# Processing Record 33 of Set 12 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=fort bragg
# Processing Record 34 of Set 12 | fort bragg
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=sao vicente
# Processing Record 35 of Set 12 | sao vicente
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=north scituate
# Processing Record 36 of Set 12 | north scituate
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=masaurhi buzurg
# Processing Record 37 of Set 12 | masaurhi buzurg
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=munderkingen
# Processing Record 38 of Set 12 | munderkingen
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=taoudenni
# Processing Record 39 of Set 12 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=puerto lempira
# Processing Record 40 of Set 12 | puerto lempira
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=gunjur
# Processing Record 41 of Set 12 | gunjur
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=khao yoi
# Processing Record 42 of Set 12 | khao yoi
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=port alberni
# Processing Record 43 of Set 12 | port alberni
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=kattivakkam
# Processing Record 44 of Set 12 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zapolyarnyy
# Processing Record 45 of Set 12 | zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=shakhan
# Processing Record 46 of Set 12 | shakhan
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=farafangana
# Processing Record 47 of Set 12 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=yanchep
# Processing Record 48 of Set 12 | yanchep
# http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=f875ff34c9777b66cf2f727109ef99f1&q=zhengjiatun
# Processing Record 49 of Set 12 | zhengjiatun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           st. john's  47.5649  -52.7093     20.71        92         100
# 1    armacao de buzios -22.7469  -41.8817     27.09        80           0
# 2    port-aux-francais -49.3500   70.2167      2.99        77          26
# 3        port mathurin -19.6833   63.4167     22.87        72           0
# 4        fort mcmurray  56.7268 -111.3810     21.73        60           0
# ..                 ...      ...       ...       ...       ...         ...
# 565        zapolyarnyy  69.4154   30.8136     17.60        67          14
# 566            shakhan  49.8233   72.6342     20.96        53          49
# 567        farafangana -22.8167   47.8333     21.47        84          74
# 568            yanchep -31.5500  115.6833     17.19        92          99
# 569        zhengjiatun  43.5064  123.5064     21.93        93          75
#
#      Wind Speed Country        Date
# 0         10.29      CA  1722973155
# 1         10.52      BR  1722973265
# 2          5.90      TF  1722973265
# 3          4.78      MU  1722973265
# 4          3.09      CA  1722973265
# ..          ...     ...         ...
# 565        0.84      RU  1722973311
# 566        3.23      KZ  1722973311
# 567        0.77      MG  1722973311
# 568        9.64      AU  1722973312
# 569        2.97      CN  1722973312
#
# [570 rows x 9 columns]

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         st. john's  47.5649  -52.7093     20.71        92         100
# 1  armacao de buzios -22.7469  -41.8817     27.09        80           0
# 2  port-aux-francais -49.3500   70.2167      2.99        77          26
# 3      port mathurin -19.6833   63.4167     22.87        72           0
# 4      fort mcmurray  56.7268 -111.3810     21.73        60           0
#
#    Wind Speed Country        Date
# 0       10.29      CA  1722973155
# 1       10.52      BR  1722973265
# 2        5.90      TF  1722973265
# 3        4.78      MU  1722973265
# 4        3.09      CA  1722973265

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               st. john's  47.5649  -52.7093     20.71        92         100
# 1        armacao de buzios -22.7469  -41.8817     27.09        80           0
# 2        port-aux-francais -49.3500   70.2167      2.99        77          26
# 3            port mathurin -19.6833   63.4167     22.87        72           0
# 4            fort mcmurray  56.7268 -111.3810     21.73        60           0
#
#          Wind Speed Country        Date
# City_ID
# 0             10.29      CA  1722973155
# 1             10.52      BR  1722973265
# 2              5.90      TF  1722973265
# 3              4.78      MU  1722973265
# 4              3.09      CA  1722973265

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness (&) ")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Wind Speed m/s")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 # Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
#       2 # YOUR CODE HERE
#       3
#       4 # Display sample data
# ----> 5 northern_hemi_df.head()
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
